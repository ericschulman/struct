# %%
import pandas
import math
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import norm
from statsmodels.sandbox.regression.gmm import GMM
from statsmodels.base.model import GenericLikelihoodModel

# %%
data3 = np.genfromtxt('data3.dat', delimiter='  ')
data3 = data3.transpose()
drawsml = np.genfromtxt('drawsml.dat', delimiter='  ')
drawsgmm = np.genfromtxt('drawsgmm.dat', delimiter='  ')

# %%
print len(drawsgmm[1][0:len(drawsgmm[1])/2])
print len(drawsgmm[1][20:len(drawsgmm[1])])
# Out:
# 20
# 20

# %%
def sim_eps(t1,t2,sigma,y,x1,x2,eps1):
    eps2 = 0
    for s in range(len(eps1)):
        #this expression may be wrong
        z = 100-np.exp(t1 + t2*x1+ sigma*eps1[s]) - t1 -t2*x2 - 3*y
        eps2 = eps2 + np.log(max(z,.00001))
    return eps2/len(eps1)


def sim_ll(y,x1,x2,t1,t2,sigma):
    #hard coded draws
    eps1 = np.genfromtxt('drawsml.dat', delimiter='  ')
    ll = 0
    for i in range(len(eps1)):
        #run simulation
        eps2 = sim_eps(t1,t2,sigma,y[i],x1[i],x2[i],eps1[i])
        ll = ll + norm(0,sigma).logpdf(eps2)
    return ll


class part_b(GenericLikelihoodModel):
    
    def nloglikeobs(self, params):
        t1, t2, sigma = params
        y = self.endog
        x1,x2 = self.exog.transpose()
        return -sim_ll(y, x1,x2,t1,t2,sigma)

    
    def fit(self, start_params=None, maxiter=10000, maxfun=5000, **kwds):
        # we have one additional parameter and we need to add it for summary
        self.exog_names.append('sigma')
        if start_params == None:
            # Reasonable starting values
            start_params = np.append(np.zeros(self.exog.shape[1]), [.5])
        return super(part_b, self).fit(start_params=start_params, maxiter=maxiter, maxfun=maxfun, **kwds)

    
model_b = part_b(data3[0],data3[1:].transpose()).fit()
print(model_b.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 3.862409
#          Iterations: 65
#          Function evaluations: 124
#                                 part_b Results
# ==============================================================================
# Dep. Variable:                      y   Log-Likelihood:                -193.12
# Model:                         part_b   AIC:                             390.2
# Method:            Maximum Likelihood   BIC:                             394.1
# Date:                Mon, 17 Sep 2018
# Time:                        18:39:51
# No. Observations:                  50
# Df Residuals:                      48
# Df Model:                           1
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0532        nan        nan        nan         nan         nan
# x2            -0.0596        nan        nan        nan         nan         nan
# sigma         11.5130        nan        nan        nan         nan         nan
# ==============================================================================
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/statsmodels/base/model.py:488: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   'available', HessianInversionWarning)

# %%
def sim_g(t1,t2,sigma,y,x1,x2,eps1,eps2):
    g = 0
    for s in range(len(eps1)):
        #this expression may be wrong
        g = g + y - (( 100 - np.exp(t1 + t2*x1 + eps1[s]) - np.exp(t1 + t2*x2 + eps2[s]) )/3)
    return g/ (len(eps1)*len(eps2))


def sim_g_sq(t1,t2,sigma,y,x1,x2,eps1,eps2):
    g = 0
    for s in range(len(eps1)):
        #this expression may be wrong
        g = g + y**2 -  ((100 - np.exp(t1 + t2*x1 + eps1[s]) - np.exp(t1 + t2*x2 + eps2[s])  )/3)**2
    return g/(len(eps1)*len(eps2))


class part_c(GMM):
    def __init__(self, *args, **kwds):
        # set appropriate counts for moment conditions and parameters
        kwds.setdefault('k_moms', 4)
        kwds.setdefault('k_params',3)
        super(part_c, self).__init__(*args, **kwds)

    def momcond(self, params):
        t1,t2, sigma = params   
        y = self.endog
        x1,x2 = self.exog.transpose()
        
        #initialize draws
        eps = np.genfromtxt('drawsgmm.dat', delimiter='  ').transpose()
        eps1 = eps[0:len(eps)/2]
        eps2 = eps[len(eps)/2:len(eps)]
        #calc moment conditions
        g = sim_g(t1,t2,sigma,y,x1,x2,eps1,eps2)
        g_sq = sim_g_sq(t1,t2,sigma,y,x1,x2,eps1,eps2)
        
        return np.column_stack((g,g*x1,g*x2,g_sq))


model_c = part_c(data3[0],data3[1:].transpose(), None)
beta0 = np.array([-.5, -.5, 11])
resc = model_c.fit(beta0, maxiter=2, optim_method='nm', wargs=dict(centered=False))
print(resc.summary())
# Out:
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# Optimization terminated successfully.
#          Current function value: 39.597452
#          Iterations: 44
#          Function evaluations: 148
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# Optimization terminated successfully.
#          Current function value: 0.999813
#          Iterations: 19
#          Function evaluations: 94
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# 20
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-75-0004eda1b666> in <module>()
#      41 model_c = part_c(data3[0],data3[1:].transpose(), None)
#      42 beta0 = np.array([-.5, -.5, 11])
# ---> 43 resc = model_c.fit(beta0, maxiter=2, optim_method='nm', wargs=dict(centered=False))
#      44 print(resc.summary())
#
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/statsmodels/sandbox/regression/gmm.pyc in fit(self, start_params, maxiter, inv_weights, weights_method, wargs, has_optimal_weights, optim_method, optim_args)
#     704                                         wargs = wargs,
#     705                                         options_other = options_other,
# --> 706                                         optim_args = optim_args)
#     707
#     708         self.results = results # FIXME: remove, still keeping it temporarily
#
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/statsmodels/sandbox/regression/gmm.pyc in __init__(self, *args, **kwds)
#    1132         self.df_resid = np.inf
#    1133
# -> 1134         self.cov_params_default = self._cov_params()
#    1135
#    1136
#
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/statsmodels/sandbox/regression/gmm.pyc in _cov_params(self, **kwds)
#    1168         gradmoms = self.model.gradient_momcond(self.params)
#    1169         moms = self.model.momcond(self.params)
# -> 1170         covparams = self.calc_cov_params(moms, gradmoms, **kwds)
#    1171
#    1172         return covparams
#
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/statsmodels/sandbox/regression/gmm.pyc in calc_cov_params(self, moms, gradmoms, weights, use_weights, has_optimal_weights, weights_method, wargs)
#    1216             # TOD0 make has_optimal_weights depend on convergence or iter >2
#    1217             cov = np.linalg.inv(np.dot(gradmoms.T,
# -> 1218                                     np.dot(np.linalg.inv(omegahat), gradmoms)))
#    1219         else:
#    1220             gw = np.dot(gradmoms.T, weights)
#
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in inv(a)
#     526     signature = 'D->D' if isComplexType(t) else 'd->d'
#     527     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 528     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     529     return wrap(ainv.astype(result_t, copy=False))
#     530
#
# /home/erichschulman/anaconda2/lib/python2.7/site-packages/numpy/linalg/linalg.pyc in _raise_linalgerror_singular(err, flag)
#      87
#      88 def _raise_linalgerror_singular(err, flag):
# ---> 89     raise LinAlgError("Singular matrix")
#      90
#      91 def _raise_linalgerror_nonposdef(err, flag):
#
# LinAlgError: Singular matrix
